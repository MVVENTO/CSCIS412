# %% [markdown]
# # Accidental Data Leakage Demo
#
# This notebook demonstrates how an employee can accidentally expose confidential data by pasting internal material into an AI tool.
#
# The workflow includes:
# - a fake internal dataset with customers, invoices, confidential project notes, meeting notes, and fake API keys
# - a local SQLite database that stores both the source data and the AI-tool retention artifacts
# - a simulated prompt submission that leaks sensitive information into chat logs, browser history, telemetry, vendor logs, and optional conversation memory
# - outputs you can screenshot for your paper

# %%
from pathlib import Path
import sqlite3

import pandas as pd
from IPython.display import Markdown, display

from accidental_data_leakage_demo import (
    RISK_STATEMENT,
    build_leaky_prompt,
    build_storage_summary,
    fetch_session_artifacts,
    initialize_demo_database,
    load_source_tables,
    render_flow_diagram,
    seed_demo_database,
    simulate_accidental_leakage,
)

# %% [markdown]
# ## Database Setup
#
# This cell creates the SQLite database file under `data/` and seeds the fake internal records.

# %%
DB_PATH = Path("data/accidental_data_leakage_demo.db")
MEMORY_ENABLED = True
VENDOR_LOGGING_ENABLED = True
TOOL_NAME = "Internal Productivity Copilot"

initialize_demo_database(DB_PATH)
seed_counts = seed_demo_database(DB_PATH)

pd.DataFrame(
    [{"table": name, "rows_seeded": count} for name, count in seed_counts.items()]
)
# Out:
#            table  rows_seeded
# 0      customers            2
# 1       invoices            2
# 2  project_notes            2
# 3       api_keys            2
# 4  meeting_notes            2

# %% [markdown]
# ## Fake Internal Dataset
#
# These are the internal records the employee should not paste into an external or semi-external AI workflow.

# %%
source_tables = load_source_tables(DB_PATH)

for table_name, frame in source_tables.items():
    display(Markdown(f"### {table_name.replace('_', ' ').title()}"))
    display(frame)
# Out:
# ### Customers
#   customer_id        company_name contact_name                 contact_email  \
# 0   CUST-1001  Northwind Surgical   Maya Patel  maya.patel@northwind.example
# 1   CUST-1002    Lakeview Clinics   Ethan Ross   ethan.ross@lakeview.example
#
#     plan_tier renewal_date
# 0  Enterprise   2026-05-15
# 1    Business   2026-06-01
# ### Invoices
#   invoice_id customer_id  amount_due currency    due_date   status  \
# 0   INV-1048   CUST-1001     48250.0      USD  2026-04-30  Overdue
# 1   INV-1051   CUST-1002     19300.0      USD  2026-05-08     Open
#
#    bank_reference
# 0  ACCT-7781-FAKE
# 1  ACCT-4419-FAKE
# ### Project Notes
#      project_code classification              owner  \
# 0  PRJ-AURORA-221   Confidential  Platform Security
# 1   PRJ-DELTA-118       Internal    Finance Systems
#
#                                            note_text
# 0  Project Aurora is preparing a beta rollout tha...
# 1  Delta will replace the legacy invoice approval...
# ### Api Keys
#          system_name environment                       api_key     owner  \
# 0  claims-summarizer     staging   sk-demo-aurora-7F4X9Q2L8M1N   A. Chen
# 1   billing-exporter     sandbox  sk-demo-billing-5Q1L2M8R4T7Z  K. Lewis
#
#   rotation_due
# 0   2026-05-01
# 1   2026-05-10
# ### Meeting Notes
#   meeting_id meeting_date                             attendees  \
# 0   MEET-302   2026-04-17  Sales Ops, Finance, Customer Success
# 1   MEET-304   2026-04-18            Support, Platform Security
#
#                                            note_text
# 0  Finance approved a 12 percent discount for Nor...
# 1  Do not share sandbox credentials in external s...

# %% [markdown]
# ## Prompt That Causes the Leak
#
# The employee is trying to get help writing a renewal summary, but the pasted prompt contains confidential data from several internal sources.

# %%
prompt, shared_items = build_leaky_prompt(DB_PATH)

display(Markdown("### Prompt pasted into the AI tool"))
print(prompt)

display(Markdown("### Sensitive data included in the prompt"))
shared_items
# Out:
# ### Prompt pasted into the AI tool
# Draft an executive update for tomorrow's renewal call and summarize the exposure risk.
#
# Customer context:
# - Customer ID: CUST-1001
# - Company: Northwind Surgical
# - Contact: Maya Patel
# - Contact email: maya.patel@northwind.example
# - Renewal date: 2026-05-15
#
# Billing context:
# - Invoice: INV-1048
# - Amount due: USD 48,250.00
# - Due date: 2026-04-30
# - Bank reference: ACCT-7781-FAKE
#
# Confidential project note:
# - PRJ-AURORA-221 (Confidential): Project Aurora is preparing a beta rollout that migrates 8,400 patient claim records into the internal assistant sandbox.
#
# Temporary API credential:
# - claims-summarizer staging key: sk-demo-aurora-7F4X9Q2L8M1N
#
# Meeting note:
# - Finance approved a 12 percent discount for Northwind Surgical if the renewal closes before 2026-05-15. Keep the concession internal.
#
# Please turn this into a concise customer-facing summary and tell me what issues stand out.
# ### Sensitive data included in the prompt
#     source_table   source_reference   leaked_field  \
# 0      customers          CUST-1001  contact_email
# 1       invoices           INV-1048     amount_due
# 2  project_notes     PRJ-AURORA-221      note_text
# 3       api_keys  claims-summarizer        api_key
# 4  meeting_notes           MEET-302      note_text
#
#                                         leaked_value  \
# 0                       maya.patel@northwind.example
# 1                                      USD 48,250.00
# 2  Project Aurora is preparing a beta rollout tha...
# 3                        sk-demo-aurora-7F4X9Q2L8M1N
# 4  Finance approved a 12 percent discount for Nor...
#
#                                               reason
# 0  Personally identifying customer contact inform...
# 1  Non-public financial balance and invoice refer...
# 2             Confidential internal project details.
# 3  Credential material that should never be paste...
# 4  Internal pricing strategy and discount concess...

# %% [markdown]
# ## Run the Leakage Workflow
#
# This simulates a user submitting the prompt to an internal chatbot with memory and vendor logging enabled.

# %%
result = simulate_accidental_leakage(
    DB_PATH,
    memory_enabled=MEMORY_ENABLED,
    vendor_logging_enabled=VENDOR_LOGGING_ENABLED,
    tool_name=TOOL_NAME,
)

session_id = result["session_id"]
print(f"Created demo session: {session_id}")
print(f"Sensitive matches detected in prompt: {result['prompt_summary']['total_matches']}")

pd.DataFrame(
    {
        "setting": ["memory_enabled", "vendor_logging_enabled"],
        "value": [MEMORY_ENABLED, VENDOR_LOGGING_ENABLED],
    }
)
# Out:
# Created demo session: session-20260418-113153
# Sensitive matches detected in prompt: 5
#                   setting  value
# 0          memory_enabled   True
# 1  vendor_logging_enabled   True

# %% [markdown]
# ## Where the Data Ended Up
#
# These tables show the retained artifacts after the prompt was submitted.

# %%
artifacts = fetch_session_artifacts(DB_PATH, session_id)

for name, frame in artifacts.items():
    display(Markdown(f"### {name.replace('_', ' ').title()}"))
    display(frame)
# Out:
# ### Chat Logs
#         role                                       message_text  \
# 0       user  Draft an executive update for tomorrow's renew...
# 1  assistant  I drafted a summary for Northwind Surgical, re...
#
#                               sensitive_matches_json  \
# 0  {"total_matches": 5, "counts": {"customer_id":...
# 1  {"total_matches": 1, "counts": {"invoice_id": ...
#
#                   created_at
# 0  2026-04-18T15:31:53+00:00
# 1  2026-04-18T15:31:53+00:00
# ### Browser History
#                                    page_title  \
# 0  Internal Productivity Copilot Conversation
#
#                                                  url  \
# 0  https://copilot.example.internal/chat/session-...
#
#                                              snippet  \
# 0  Draft an executive update for tomorrow's renew...
#
#                    stored_at
# 0  2026-04-18T15:31:53+00:00
# ### Telemetry Events
#          event_name  prompt_chars  contains_sensitive_data  \
# 0  prompt_submitted           890                        1
#
#                                        metadata_json  \
# 0  {"prompt_preview": "Draft an executive update ...
#
#                  captured_at
# 0  2026-04-18T15:31:53+00:00
# ### Vendor Logs
#          provider_name                                   retention_policy  \
# 0  External LLM Vendor  Retained for support and abuse monitoring in t...
#
#                                      payload_excerpt  \
# 0  Draft an executive update for tomorrow's renew...
#
#                  captured_at
# 0  2026-04-18T15:31:53+00:00
# ### Conversation Memory
#          memory_key                                       memory_value  \
# 0  customer_context  Northwind Surgical has an enterprise renewal w...
# 1   project_context  Project Aurora involves internal migration det...
# 2   pricing_context  A 12 percent discount concession was discussed...
#
#                   created_at
# 0  2026-04-18T15:31:53+00:00
# 1  2026-04-18T15:31:53+00:00
# 2  2026-04-18T15:31:53+00:00
# ### Prompt Leakage Items
#     source_table   source_reference   leaked_field  \
# 0      customers          CUST-1001  contact_email
# 1       invoices           INV-1048     amount_due
# 2  project_notes     PRJ-AURORA-221      note_text
# 3       api_keys  claims-summarizer        api_key
# 4  meeting_notes           MEET-302      note_text
#
#                                         leaked_value  \
# 0                       maya.patel@northwind.example
# 1                                      USD 48,250.00
# 2  Project Aurora is preparing a beta rollout tha...
# 3                        sk-demo-aurora-7F4X9Q2L8M1N
# 4  Finance approved a 12 percent discount for Nor...
#
#                                               reason
# 0  Personally identifying customer contact inform...
# 1  Non-public financial balance and invoice refer...
# 2             Confidential internal project details.
# 3  Credential material that should never be paste...
# 4  Internal pricing strategy and discount concess...

# %% [markdown]
# ## Direct SQL Query
#
# This cell connects to the SQLite database directly and queries the retained chat log records.

# %%
with sqlite3.connect(DB_PATH) as conn:
    sql_preview = pd.read_sql_query(
        """
        SELECT
            session_id,
            role,
            substr(message_text, 1, 120) AS preview,
            created_at
        FROM chat_logs
        ORDER BY id
        """,
        conn,
    )

sql_preview
# Out:
#                 session_id       role  \
# 0  session-20260418-113153       user
# 1  session-20260418-113153  assistant
#
#                                              preview  \
# 0  Draft an executive update for tomorrow's renew...
# 1  I drafted a summary for Northwind Surgical, re...
#
#                   created_at
# 0  2026-04-18T15:31:53+00:00
# 1  2026-04-18T15:31:53+00:00

# %% [markdown]
# ## Storage Summary
#
# This table is useful for the write-up because it maps each storage location to the retained data and the risk.

# %%
build_storage_summary(DB_PATH, session_id)
# Out:
#               location                                        stored_data  \
# 0            Chat logs  Draft an executive update for tomorrow's renew...
# 1      Browser history  Draft an executive update for tomorrow's renew...
# 2            Telemetry  {"prompt_preview": "Draft an executive update ...
# 3          Vendor logs  Draft an executive update for tomorrow's renew...
# 4  Conversation memory  Northwind Surgical has an enterprise renewal w...
#
#                                        why_it_exists  \
# 0           Conversation history and support review.
# 1  Session restore, autocomplete, and synced hist...
# 2           Analytics, debugging, and observability.
# 3    External provider support and abuse monitoring.
# 4          Future personalization and context reuse.
#
#                                                 risk
# 0  Full prompt retention preserves all pasted con...
# 1  Prompt fragments can remain on the local devic...
# 2  Prompt previews and sensitive counts leak into...
# 3   Confidential prompts leave the company boundary.
# 4  Sensitive facts can resurface in later prompts...

# %% [markdown]
# ## Data Flow Diagram
#
# User -> AI tool -> retained storage locations.

# %%
render_flow_diagram(
    tool_name=TOOL_NAME,
    memory_enabled=MEMORY_ENABLED,
    vendor_logging_enabled=VENDOR_LOGGING_ENABLED,
)

# %% [markdown]
# ## Risk Statement
#
# **Confidential data exposure via user prompts and retention.**
#
# In this demo, the user copied confidential internal material into an AI workflow for convenience. The same content was then retained in the application chat log, browser history, telemetry data, vendor-side logging, and conversation memory. That creates multiple disclosure points even though the original user action was unintentional.
